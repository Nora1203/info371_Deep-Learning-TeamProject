# %% [markdown]
# # Part 1 - EDA

# %% [markdown]
# #### 01 - Load Data and Fill NaN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./data/tweets.csv")
df.head(5)
# Out:
#                               user_name  \
# 0       Tushar Gupta at DevFest Raipur.
# 1                PharmaTechnologyTrends
# 2                           Richard Kim
# 3  GiamMa-based researchers SDR R&D IoT
# 4                      Bobby Davis, Jr.
#
#                                                 text  \
# 0  Is this the end of Twitter threads?\n#AI #Chat...
# 1  ChatGPT is a truly mind-blowing tool and playi...
# 2  #ChatGPT can be used to generate malicious cod...
# 3  Use prompt hack to bypass OpenAI's content pol...
# 4  Why #chatgpt will never replace devs. \n\nhttp...
#
#                     user_location  \
# 0                           India
# 1  Frankfurt am Main, Deutschland
# 2                             NaN
# 3                             NaN
# 4                  North Carolina
#
#                                     user_description  \
# 0  •Experiencing Life💬 && Tech🥑 •Learning about💻:...
# 1  Latest News and Trends in Pharmaceutical Industry
# 2  News, papers, and books on AI, Machine Learnin...
# 3  #ArtTechnology #IT #Hardware #Security #OSINT ...
# 4  CEO @CoderFoundry\nAuthor: Breaking the Code h...
#
#                 user_created  user_followers  user_friends user_favourites  \
# 0  2021-10-05 05:05:55+00:00           230.0         438.0            1567
# 1  2022-11-06 21:03:59+00:00           264.0        4333.0              24
# 2  2010-05-06 00:20:48+00:00          4481.0        4982.0           18412
# 3  2020-08-29 09:30:40+00:00          1996.0        1190.0           19528
# 4  2012-06-25 17:36:19+00:00          1182.0         245.0             888
#
#   user_verified                       date  \
# 0         False  2022-12-20 13:29:08+00:00
# 1         False  2022-12-20 13:28:50+00:00
# 2         False  2022-12-20 13:28:39+00:00
# 3         False  2022-12-20 13:28:09+00:00
# 4         False  2022-12-20 13:27:10+00:00
#
#                                             hashtags               source
# 0                                  ['AI', 'ChatGPT']  Twitter for Android
# 1                                                NaN       EveryoneSocial
# 2  ['ChatGPT', 'code', 'chatgpt', 'language', 'ai...             shem0304
# 3                                                NaN      Twitter Web App
# 4                                        ['chatgpt']  Twitter for Android

# %%
# count the number of missing value in each column
nan_count = df.isna().sum()
print("Missing values in each column in the orignial dataset:")
nan_count
# Out:
# Missing values in each column in the orignial dataset:
# user_name               2
# text                    0
# user_location       10184
# user_description     2684
# user_created            1
# user_followers          1
# user_friends            1
# user_favourites         1
# user_verified           1
# date                    1
# hashtags             6049
# source                  2
# dtype: int64

# %%
df_new = df.fillna("NaN")
df_new.head(5)
# Out:
#                               user_name  \
# 0       Tushar Gupta at DevFest Raipur.
# 1                PharmaTechnologyTrends
# 2                           Richard Kim
# 3  GiamMa-based researchers SDR R&D IoT
# 4                      Bobby Davis, Jr.
#
#                                                 text  \
# 0  Is this the end of Twitter threads?\n#AI #Chat...
# 1  ChatGPT is a truly mind-blowing tool and playi...
# 2  #ChatGPT can be used to generate malicious cod...
# 3  Use prompt hack to bypass OpenAI's content pol...
# 4  Why #chatgpt will never replace devs. \n\nhttp...
#
#                     user_location  \
# 0                           India
# 1  Frankfurt am Main, Deutschland
# 2                             NaN
# 3                             NaN
# 4                  North Carolina
#
#                                     user_description  \
# 0  •Experiencing Life💬 && Tech🥑 •Learning about💻:...
# 1  Latest News and Trends in Pharmaceutical Industry
# 2  News, papers, and books on AI, Machine Learnin...
# 3  #ArtTechnology #IT #Hardware #Security #OSINT ...
# 4  CEO @CoderFoundry\nAuthor: Breaking the Code h...
#
#                 user_created user_followers user_friends user_favourites  \
# 0  2021-10-05 05:05:55+00:00          230.0        438.0            1567
# 1  2022-11-06 21:03:59+00:00          264.0       4333.0              24
# 2  2010-05-06 00:20:48+00:00         4481.0       4982.0           18412
# 3  2020-08-29 09:30:40+00:00         1996.0       1190.0           19528
# 4  2012-06-25 17:36:19+00:00         1182.0        245.0             888
#
#   user_verified                       date  \
# 0         False  2022-12-20 13:29:08+00:00
# 1         False  2022-12-20 13:28:50+00:00
# 2         False  2022-12-20 13:28:39+00:00
# 3         False  2022-12-20 13:28:09+00:00
# 4         False  2022-12-20 13:27:10+00:00
#
#                                             hashtags               source
# 0                                  ['AI', 'ChatGPT']  Twitter for Android
# 1                                                NaN       EveryoneSocial
# 2  ['ChatGPT', 'code', 'chatgpt', 'language', 'ai...             shem0304
# 3                                                NaN      Twitter Web App
# 4                                        ['chatgpt']  Twitter for Android

# %%
# check after filling nan
nan_count_new = df_new.isna().sum()
print("Missing values in each column after filling NaN:")
nan_count_new
# Out:
# Missing values in each column after filling NaN:
# user_name           0
# text                0
# user_location       0
# user_description    0
# user_created        0
# user_followers      0
# user_friends        0
# user_favourites     0
# user_verified       0
# date                0
# hashtags            0
# source              0
# dtype: int64

# %%
num_rows, num_columns = df_new.shape

print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 39054
# Number of columns: 12

# %% [markdown]
# #### 02 - Top users who post the most tweets

# %%
top_users = df_new['user_name'].value_counts().head(10)
print("(2) Top 10 users with the most comments:")
print(top_users)
# Out:
# (2) Top 10 users with the most comments:
# user_name
# Best MidJourneyAI Generated Art🤖🎨              244
# Richard Geldreich                              216
# Richard Kim                                    103
# BeyondBacktesting                               87
# ChatGPT Chef                                    77
# @tomruen@mathstodon.xyz                         67
# Wiesław Šoltés                                  58
# Bakesbyny                                       57
# DataChazGPT (not a bot) 🤯                       51
# Cybersécurité, IA, Metavers, Cryptomonnaies     49
# Name: count, dtype: int64

# %%
df_top_users = top_users.reset_index()
df_top_users.columns = ['User Name', 'Comments Count']
df_top_users_sorted = df_top_users.sort_values('Comments Count', ascending=True)

plt.figure(figsize=(10, 8))
plt.barh(df_top_users_sorted['User Name'], df_top_users_sorted['Comments Count'], color='skyblue')
plt.xlabel('Comments Count')
plt.ylabel('User Name')
plt.title('Top 10 Users with the Most Comments')
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()
# Out:
# /opt/anaconda3/envs/nre/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129327 (\N{SHOCKED FACE WITH EXPLODING HEAD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/nre/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/nre/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### 03 - The change of tweets posted by day

# %%
df_new['date'] = pd.to_datetime(df_new['date'], format='%Y-%m-%d %H:%M:%S%z', errors='coerce')
df_new = df_new.dropna(subset=['date'])
df_new['date'] = df_new['date'].dt.date

# %%
tweet_counts = df_new.groupby('date').size()
plt.figure(figsize=(10, 6))
tweet_counts.plot(kind='bar')
plt.title('Tweet Counts by Day')
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# We could see that the number of tweets is the highest on 2022-12-06, and this number decreased in general in the following days.

# %% [markdown]
# #### 04 - Count

# %%
# non-NA values in the 'text' column

text_non_na = df_new['text'].notna().sum()
print("Number of non-NA texts:", text_non_na)
# Out:
# Number of non-NA texts: 39052

# %%
# Count unique locations

unique_locations = df_new['user_location'].nunique()
print("Number of unique user locations:", unique_locations)
# Out:
# Number of unique user locations: 7838

# %%
# Count unique descriptions

unique_descriptions = df_new['user_description'].nunique()
print("Number of unique user descriptions:", unique_descriptions)
# Out:
# Number of unique user descriptions: 23700

# %% [markdown]
# #### 05 - Top 10 descriptions

# %%
df_description = df_new.copy()
df_description = df_new[df_new['user_description'] != "NaN"]

# %%
df_description['user_description'].value_counts()
# Out:
# user_description
# follow my twitter account if you like the content :)\ni will keep posting best of the best AI generated Art. thanks.\ntelegram: https://t.co/kqCv41hsJA             244
# Co-founder of Binomial: open source GPU texture interchange. Previously: SpaceX (Starlink), Ensemble, Valve (P2/DotA2/CSGO/Linux). UAP OSINT/history buff.          216
# News, papers, and books on AI, Machine Learning, Deep Learning, Image Recognition, Computer Vision, and Natural Language Processing                                 103
# Systematic Trading, Algo Trading, Tape Reader. #ES_F, #MES_F, Futures trader. No investment advice.\n\nMy Apex Trader Funding link: https://t.co/NhZQpwonjb          87
# Cooking Interesting ChatGPT content.\n\nNote : All the content generated using ChatGPT  for Research,Fun and Entertainment purposes only. Use carefully              75
#                                                                                                                                                                    ...
# I like office supplies                                                                                                                                                1
# 44yro geek | he/him | PHP developer by trade | game developer for fun\n\nhttps://t.co/Z1SKsSVVrj                                                                      1
# 🛡️ App/Game Developer @Appsphinx | UX/Graphic Designer 𓅰                                                                                                              1
# Wanted to grow up to become Shoaib Akhtar, now work in the policy research space. Words in @Dawn_com & @TFT_. @LifeAtLUMS & @EconCalgary alumni.                      1
# Postdoc in @GippLab at @uniGoettingen \nPh.D. in CS from @UniKonstanz\nPreviously at @UCBerkeley, @jouhouken, @Uni_Wuppertal\nInterests: #NLP, #IR, #DataScience      1
# Name: count, Length: 23699, dtype: int64

# %%
top_des = df_description['user_description'].value_counts().head(10)
print("(2) Top 10 descriptions:")
print(top_des)
# Out:
# (2) Top 10 descriptions:
# user_description
# follow my twitter account if you like the content :)\ni will keep posting best of the best AI generated Art. thanks.\ntelegram: https://t.co/kqCv41hsJA        244
# Co-founder of Binomial: open source GPU texture interchange. Previously: SpaceX (Starlink), Ensemble, Valve (P2/DotA2/CSGO/Linux). UAP OSINT/history buff.     216
# News, papers, and books on AI, Machine Learning, Deep Learning, Image Recognition, Computer Vision, and Natural Language Processing                            103
# Systematic Trading, Algo Trading, Tape Reader. #ES_F, #MES_F, Futures trader. No investment advice.\n\nMy Apex Trader Funding link: https://t.co/NhZQpwonjb     87
# Cooking Interesting ChatGPT content.\n\nNote : All the content generated using ChatGPT  for Research,Fun and Entertainment purposes only. Use carefully         75
# ∙ Developer 🥑 at 🎈@Streamlit ❄️@snowflakedb \n∙ 🧙‍♂️ Open Sourcerer\n∙ Joining the dots between SEO & #DataScience\n∙ @SEOPythonistas maintainer 🐍🔥 \n🇫🇷 🇬🇧     69
# I share geometry, astronomy and interesting things. It is hard to avoid politics, but may delete quickly. Stand w/🇺🇦. ekorb si ksuM nolE                        67
# Bakes by NY | BBNY. Visit https://t.co/PxmcWyhsdt or WA 81233953 for orders or enquiries. 😊                                                                     57
# Top 10 Influencers #insurtech / #cybersecurity #Metaverse #AI #crypto #intelligenceartificielle #cybersecurite #bitcoin @Probe_IT_                              49
# @soltes@mastodon.social                                                                                                                                         48
# Name: count, dtype: int64

# %%
df_top_des = top_des.reset_index()
df_top_des.columns = ['user_description', 'Comments Count']
df_top_des_sorted = df_top_des.sort_values('Comments Count', ascending=True)

# %%
# plt.rcParams['font.family'] = 'DejaVu Sans'

plt.figure(figsize=(12, 10))
plt.subplots_adjust(left=0.3) 
plt.barh(df_top_des_sorted['user_description'], df_top_des_sorted['Comments Count'], color='skyblue', height=0.8)
plt.xlabel('Comments Count')
plt.ylabel('User Description')
plt.title('Top 10 User Descriptions with the Most Comments')
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# #### 06 -  User followers intervals

# %%
df_follower = df_new.copy()
df_follower['user_followers'] = pd.to_numeric(df_new['user_followers'], errors='coerce')
bins = [0, 100, 1000, 10000, 100000, 1000000, np.inf]
followers_intervals = pd.cut(df_follower['user_followers'], bins=bins)
followers_interval_counts = followers_intervals.value_counts()

print("User followers intervals:")
print(followers_interval_counts)
# Out:
# User followers intervals:
# user_followers
# (100.0, 1000.0]          14515
# (0.0, 100.0]             11282
# (1000.0, 10000.0]         9768
# (10000.0, 100000.0]       2376
# (100000.0, 1000000.0]      317
# (1000000.0, inf]            33
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
plt.bar(followers_interval_counts.index.astype(str), followers_interval_counts.values, color='skyblue')
plt.xlabel('Followers Intervals')
plt.ylabel('Number of Followers')
plt.title('User Followers Distribution')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# Most users has a the number of followers between 100 and 1000, while only a small amount of users have a number of followers larger than 100000.

# %% [markdown]
# #### 07 - User friends intervals

# %%
df_friends = df_new.copy()
df_friends['user_friends'] = pd.to_numeric(df_new['user_friends'], errors='coerce')
bins = [0, 100, 1000, 10000, 100000, 1000000, np.inf]
friends_intervals = pd.cut(df_friends['user_friends'], bins=bins)
friends_interval_counts = friends_intervals.value_counts()

print("User user_friends intervals:")
print(friends_interval_counts)
# Out:
# User user_friends intervals:
# user_friends
# (100.0, 1000.0]          20075
# (1000.0, 10000.0]        10496
# (0.0, 100.0]              7591
# (10000.0, 100000.0]        424
# (100000.0, 1000000.0]       17
# (1000000.0, inf]             0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
plt.bar(friends_interval_counts.index.astype(str), friends_interval_counts.values, color='skyblue')
plt.xlabel('Friends Intervals')
plt.ylabel('Number of Friends')
plt.title('User Friends Distribution')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# As similar pattern shown above, most of the users have the number of friends between 100 to 1000, but only a small amount of users has number of friends larger than 10000.

# %% [markdown]
# #### 08 - Distribution

# %%
df['text_length'] = df['text'].astype(str).apply(len)
df['description_length'] = df['user_description'].astype(str).apply(len)

# %%
# Text Length
plt.figure(figsize=(8, 6))
sns.histplot(df['text_length'], kde=True)
plt.title('Text Length Distribution')
plt.show()

# user_description Length
plt.figure(figsize=(8, 6))
sns.histplot(df['description_length'], kde=True)
plt.title('User Description Length Distribution')
plt.show()

# %%
df_distribution = df.copy()
df_distribution = df_distribution[
    df_distribution['user_followers'].apply(lambda x: isinstance(x, (int, float, np.int64, np.float64))) &
    df_distribution['user_friends'].apply(lambda x: isinstance(x, (int, float, np.int64, np.float64))) &
    df_distribution['user_favourites'].apply(lambda x: isinstance(x, (int, float, np.int64, np.float64)))
]

# %%
# user_followers Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['user_followers'], kde=True, log_scale=True)
plt.title('User Followers Count Distribution (Log Scale)')
plt.show()
# Out:
# /opt/anaconda3/envs/nre/lib/python3.9/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %%
# user_friends Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['user_friends'], kde=True, log_scale=True)
plt.title('User Friends Count Distribution (Log Scale)')
plt.show()
# Out:
# /opt/anaconda3/envs/nre/lib/python3.9/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %%
# user_favourites Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['user_favourites'], kde=True, log_scale=True)
plt.title('User Favourites Count Distribution (Log Scale)')
plt.show()
# Out:
# /opt/anaconda3/envs/nre/lib/python3.9/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
